# %% [markdown]
# <a href="https://colab.research.google.com/github/sanvika15/Colab/blob/main/CV_p1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PRACTICAL NO: 1 (B)**

# %% [markdown]
# # Name: Sanvika Dakhale
#
# # Batch: B1
#
# # Roll no: 18

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab import files

import numpy as np

# %%
#upload and load image
uploaded = files.upload()
image_path = list(uploaded.keys())[0]
img = cv2.cvtColor(cv2.imread(image_path),cv2.COLOR_BGR2RGB)
# Out:
#      <input type="file" id="files-315a5ffa-c03e-497b-89f2-cef94b49260b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-315a5ffa-c03e-497b-89f2-cef94b49260b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#original image
img = cv2.imread("tree.jpg")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
#translation
mg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
tx, ty = 10, 20
translation_matrix = np.float32([[1, 0, tx], [0, 1, ty]])
img_translation = cv2.warpAffine(img, translation_matrix, (img.shape[1], img.shape[0]))
plt.imshow(img_translation)
plt.axis('off')
plt.show()

# %%
#rotation by 30
center = (img.shape[1]//2, img.shape[0]//2)
rotation_matrix = cv2.getRotationMatrix2D(center, 30, 1)
rotated_img = cv2.warpAffine(img, rotation_matrix, (img.shape[1], img.shape[0]))
plt.imshow(rotated_img)
plt.axis('off')
plt.show()

# %%
#rotation by 90
img = cv2.imread("tree.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
rows, cols = img.shape[:2]
rot_matrix = cv2.getRotationMatrix2D((cols / 2, rows / 2), 90, 1)
dst = cv2.warpAffine(img, rot_matrix, (cols, rows))
plt.imshow(dst)
plt.axis('off')
plt.show()

# %%
#scaling
scaled_img = cv2.resize(img, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_CUBIC)
plt.imshow(scaled_img)
plt.axis('off')
plt.show()

# %%
#shearing
img = cv2.imread('tree.jpg')
shear_factor = 0.2
shear_matrix = np.array([[1, shear_factor, 0], [shear_factor, 1, 0]], dtype=np.float32)
img_sheared = cv2.warpAffine(img, shear_matrix, (img.shape[1], img.shape[0]))
plt.imshow(img_sheared)
plt.axis('off')
plt.show()

# %%
#reflection
rows, cols = img.shape[:2]
reflect_matrix = np.float32([[-1, 0, cols], [0, 1, 0]])
reflected = cv2.warpAffine(img, reflect_matrix, (img.shape[1], img.shape[0]))
plt.imshow(reflected)
plt.axis('off')
plt.show()
